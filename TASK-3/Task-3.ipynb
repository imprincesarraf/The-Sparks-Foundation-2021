# %% [markdown]
# # NAME: PRINCE SARRAF
#
# ### The Sparks Foundation-Data science and Business Analytics Intern
# ### Task-3
# ##### Problem statement: As a Business Manager, try to find out the weak areas where you can work to make more profit

# %%
import pandas as pd
df=pd.read_csv("SampleSuperStore.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# Clearly,there are no null values

# %%
df.drop('Postal Code',axis=1,inplace=True)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df.shape
# Out:
# (9994, 12)

# %%
df.info
# Out:
# <bound method DataFrame.info of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# Number of unique values in each column

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ## DATA VISUALIZATION
# ### Univariate Analysis

# %%
df["Ship Mode"].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
(df["Ship Mode"].value_counts()/len(df["Ship Mode"]))*100
# Out:
# Standard Class    59.715829
# Second Class      19.461677
# First Class       15.389234
# Same Day           5.433260
# Name: Ship Mode, dtype: float64

# %%
((df["Ship Mode"].value_counts()/len(df["Ship Mode"]))*100).plot(kind="bar",color="green")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusions from above graph:
# #### 1.More than 50% deliveries are from standard class
# #### 2.Very less deliveries are done on same day

# %%
df["Segment"].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
(df["Segment"].value_counts()/len(df["Segment"])*100)
# Out:
# Consumer       51.941165
# Corporate      30.218131
# Home Office    17.840704
# Name: Segment, dtype: float64

# %%
(df["Segment"].value_counts()/len(df["Segment"])*100).plot(kind="bar",color="red")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusions from the above graph:
# ####  1.More than 50% people belong to consumer class
# #### 2. Almost 30% people belong to Corporate class
# #### 3. Almost 18% people belong to Home Office class

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
(df['Category'].value_counts()/len(df['Category'])*100)
# Out:
# Office Supplies    60.296178
# Furniture          21.222734
# Technology         18.481089
# Name: Category, dtype: float64

# %%
(df['Category'].value_counts()/len(df['Category'])*100).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Conclusions made from above graph
# #### 1. Almost 60% of products belong to Office Supplies
# #### 2. Almost 20% of products belong to Furniture
# #### 3. Almost 18% of products belong to Technology

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
(df['Sub-Category'].value_counts()/len(df['Sub-Category'])*100)
# Out:
# Binders        15.239143
# Paper          13.708225
# Furnishings     9.575745
# Phones          8.895337
# Storage         8.465079
# Art             7.964779
# Accessories     7.754653
# Chairs          6.173704
# Appliances      4.662798
# Labels          3.642185
# Tables          3.191915
# Envelopes       2.541525
# Bookcases       2.281369
# Fasteners       2.171303
# Supplies        1.901141
# Machines        1.150690
# Copiers         0.680408
# Name: Sub-Category, dtype: float64

# %%
(df['Sub-Category'].value_counts()/len(df['Sub-Category'])*100).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Conclusions from above graph:
# ###### 1. Blinders and Paper have the highest quantity

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
df.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
import seaborn as sns
sns.pairplot(df.select_dtypes(exclude=["object"]))

# %%
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataplot = sn.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# #### Clearly the discount and profit are highly negatively corelated
# ###### Values closer to 0 implies that there is no linear dependency between the variables
# ###### Values closer to 1 implies that all data points lie on a line for which Y increases as X increases
# ###### Values closer to -1 implies that all data points lie on a line for which Y increases as X decreases

# %%
plt.figure(figsize=(1,1))
df.groupby('Category')['Profit','Sales','Discount'].sum().plot(kind="bar")
plt.show()
# Out:
# C:\Users\princ\AppData\Local\Temp/ipykernel_18848/3709617526.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Category')['Profit','Sales','Discount'].sum().plot(kind="bar")

# %% [markdown]
# ##### From the above graph clearly sales of  furniture is  good but still profit is lowest

# %%
plt.figure(figsize=(1,1))
df.groupby('Sub-Category')['Sales','Discount','Profit'].sum().plot(kind='bar')
plt.show()
# Out:
# C:\Users\princ\AppData\Local\Temp/ipykernel_18848/3845752130.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Sub-Category')['Sales','Discount','Profit'].sum().plot(kind='bar')

# %%
plt.figure(figsize=(5,5))
df.groupby('Sub-Category')['Sales'].sum().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(5,5))
df.groupby('Sub-Category')['Profit'].sum().plot(kind='bar')
plt.show()

# %% [markdown]
# ##### From the above graph we can see that:
# ###### Sales of tables is high but it is producing loss
# ###### There is negligible loss from Bookcases and Supplies
# ###### There is negligible sales and profit from fasteners
# ###### Copiers are giving highest profit

# %%
plt.figure(figsize=(1,1))
df.groupby('Region')['Sales','Discount','Profit'].sum().plot(kind='bar')
plt.show()
# Out:
# C:\Users\princ\AppData\Local\Temp/ipykernel_18848/3683326295.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Region')['Sales','Discount','Profit'].sum().plot(kind='bar')

# %%
sns.barplot(x=df.Region,y=df.Sales)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
sns.barplot(x=df.Region,y=df.Profit)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
sns.barplot(x=df.Region,y=df.Profit,hue=df.Category)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %% [markdown]
# #### Furniture is making loss from Central region
# #### Technology is giving highest profit from all the region

# %%
sns.barplot(x=df.Region,y=df.Profit,hue=df.Segment)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %% [markdown]
# #### From the above graph we can see that:
# ##### lowest profit is from central region in consumer segment
# ##### Highest profit is from East region in Home office segment

# %%
df1=df.groupby('State')['Profit','Sales'].sum()
df1.plot.bar(figsize=(20,10))
# Out:
# C:\Users\princ\AppData\Local\Temp/ipykernel_18848/4125226067.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1=df.groupby('State')['Profit','Sales'].sum()
# <AxesSubplot:xlabel='State'>

# %%
df1=df.groupby('State')['Profit'].sum()
df1.plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='State'>

# %% [markdown]
# #### From the above graph we can see that:
# ##### 1.Sales  and Profit in California and New York is more
# ##### 2. States like Arizona,Colorado,Flordia,IIinois,North Carolina,Ohio,Pennsylvania,Tennessee,Texas are making loss

# %%
df2=df.groupby('State')['Discount'].sum()
plt.xlabel("States")
plt.ylabel("Discount")
df2.plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='State', ylabel='Discount'>

# %% [markdown]
# #### Texas, Arizona,Colorado,Flordia,IIinois,North Carolina,Ohio,Pennsylvania,Tennessee these states are giving good discounts which results loss

# %% [markdown]
# ## Final Conclusion
# #### 1.The sales of tables should be stopped as it is producing high loss
# #### 2. Bookcases and Supplies are producing negligible loss so their price should be increased
# #### 3. The price of Furniture should be increased as sales is High but profit is lowest
# #### 4. Furniture is making loss from Central region so price should be increased specially in central region
# #### 5. Texas, Arizona,Colorado,Flordia,IIinois,North Carolina,Ohio,Pennsylvania,Tennessee these states are giving loss even when the sale is good the region behind these losses are high discounts.So we need to reduce the discount in these states to make profit
